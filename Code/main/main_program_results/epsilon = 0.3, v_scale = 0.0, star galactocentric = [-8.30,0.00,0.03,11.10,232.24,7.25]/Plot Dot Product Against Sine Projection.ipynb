# %%
import numpy as np
projection_data = np.load("projection/projection data.npz")
cluster = projection_data["cluster"]
projection = projection_data["result"]
dot_data = np.load("dot product/data.npz")
dot = dot_data["result"]
dot = np.nanmax(np.abs(dot), axis =1)
# Out:
# c:\users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: All-NaN slice encountered
#   import sys

# %%
import matplotlib.pyplot as plt
plt.scatter(dot, projection)
plt.xlabel("dot product")
plt.ylabel("sine projection")
# Out:
# Text(0,0.5,'sine projection')

# %%
np.shape(projection)
# Out:
# (794,)

# %%
np.shape(dot)
# Out:
# (794,)
