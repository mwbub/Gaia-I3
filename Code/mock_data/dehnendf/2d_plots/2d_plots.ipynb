# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = '../main_program_results/dehnendf_psp.npz'
data = np.load(filename)
centres = data['cluster']
values = data['result']

# %%
plt.figure(figsize=(10,8), facecolor='black')
plt.style.use("dark_background")
plt.scatter(*centres.T[[0,1]], c=np.max(np.abs(values), axis=1), marker='.', s=5, cmap='plasma')
plt.colorbar(label='Maximum Absolute Dot Product')
plt.xlabel('$x/R_0$')
plt.ylabel('$y/R_0$')
plt.title('Dehnen DF with PowerSphericalPotential, 1.7 Million Stars')
plt.show()
# Out:
# c:\program files\python36\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %%
plt.figure(figsize=(10,8), facecolor='black')
plt.style.use("dark_background")
plt.scatter(*centres.T[[0,2]], c=np.max(np.abs(values), axis=1), marker='.', s=5, cmap='plasma')
plt.colorbar(label='Maximum Absolute Dot Product')
plt.xlabel('$x/R_0$')
plt.ylabel('$z/R_0$')
plt.title('Dehnen DF with PowerSphericalPotential, 1.7 Million Stars')
plt.show()
# Out:
# c:\program files\python36\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %%
plt.figure(figsize=(10,8), facecolor='black')
plt.style.use("dark_background")
plt.scatter(*centres.T[[1,2]], c=np.max(np.abs(values), axis=1), marker='.', s=5, cmap='plasma')
plt.colorbar(label='Maximum Absolute Dot Product')
plt.xlabel('$y/R_0$')
plt.ylabel('$z/R_0$')
plt.title('Dehnen DF with PowerSphericalPotential, 1.7 Million Stars')
plt.show()
# Out:
# c:\program files\python36\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
