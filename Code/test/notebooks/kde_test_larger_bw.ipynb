# %%
#Importing the required modules and general setup
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KernelDensity
from galpy.util.bovy_coords import *
from search_local import *

gaia_data = search_phase_space(0., 0., 0., 0., 0., 0., 0.5, 0.)
R, phi, z = rect_to_cyl(gaia_data[:,0], gaia_data[:,1], gaia_data[:,2])
vR, vT, vz = rect_to_cyl_vec(gaia_data[:,3], gaia_data[:,4], gaia_data[:,5], gaia_data[:,0], gaia_data[:,1], gaia_data[:,2])
gaia_data = np.stack((R, phi, z, vR, vT, vz), axis=1)

print('#stars', len(gaia_data))
print('min/max/mean (R)', min(gaia_data[:,0]), max(gaia_data[:,0]), np.mean(gaia_data[:,0]))
print('min/max/mean (phi)', min(gaia_data[:,1]), max(gaia_data[:,1]), np.mean(gaia_data[:,1]))
print('min/max/mean (z)', min(gaia_data[:,2]), max(gaia_data[:,2]), np.mean(gaia_data[:,2]))
print('min/max/mean (vR)', min(gaia_data[:,3]), max(gaia_data[:,3]), np.mean(gaia_data[:,3]))
print('min/max/mean (vT)', min(gaia_data[:,4]), max(gaia_data[:,4]), np.mean(gaia_data[:,4]))
print('min/max/mean (vz)', min(gaia_data[:,5]), max(gaia_data[:,5]), np.mean(gaia_data[:,5]))
print(np.std(gaia_data[:,0]), np.std(gaia_data[:,1]), np.std(gaia_data[:,2]), np.std(gaia_data[:,3]), np.std(gaia_data[:,4]), np.std(gaia_data[:,5]))
# Out:
# #stars 1699708
# min/max/mean (R) 7.800911997788074 8.799620277350543 8.291940989763331
# min/max/mean (phi) 3.0813469383936956 3.2018352601712126 3.141300302894572
# min/max/mean (z) -0.47224099228924643 0.5251864323212104 0.020554162071444157
# min/max/mean (vR) -548.5939275793445 657.8733574312542 -1.0635896390181552
# min/max/mean (vT) -908.3028370417318 407.85361294256495 -210.4756252801884
# min/max/mean (vz) -392.75735712064113 374.51594061818395 -0.5273981260258953
# 0.19569240168043248 0.024711492153012812 0.16310598222016867 37.24396957743784 27.049247224061276 19.622803785914808

# %%
#Importing the required modules
import numpy as np
from sklearn.neighbors import KernelDensity

#Defining a KDE function to quickly compute probabilities for the data set
def generate_KDE(inputs, ker):
    """
    NAME:
        generate_KDE
    
    PURPOSE:
        Given an NxM matrix for inputs and one of six avaliable ker strings, 
        outputs a function `input_DKE` that treats the density estimate as a 
        black box function that can be sampled.
    
    INPUT:
        inputs (ndarray) = An NxM matrix where N is the number of data 
                           points and M is the number of parameters.
        ker (string) = One of the 6 avaliable kernel types (gaussian, 
                       tophat, epanechnikov, exponential, linear, cosine).
    
    OUTPUT:
        input_KDE (function) = A blackbox function for the density estimate
                               used for sampling data.
                               
    HISTORY:
        2018-07-15 - Updated - Ayush Pandhi
    """
    #Scaling velocities with z-score
    inputs_std = np.nanstd(inputs, axis=0)
    i1, i2, i3, i4, i5, i6 = np.mean(inputs, axis=0)
    inputs_mean = np.hstack((i1, i2, i3, i4, i5, i6))
    inputs = (inputs - inputs_mean)/inputs_std
    
    #Optimizing bandwidth in terms of Scott's Multivariate Rule of Thumb
    shape_string = str(inputs.shape)
    objects, parameters = shape_string.split(', ')
    N_string = objects[1:]
    N = int(N_string)
    bw = 10 * np.nanstd(inputs) * N ** (-1/10.)
    
    #Fit data points to selected kernel and bandwidth
    kde = KernelDensity(kernel=ker, bandwidth=bw).fit(inputs)  
    
    def input_KDE(samples):
        """
        NAME:
            input_KDE
    
        PURPOSE:
            Given a QxM matrix for samples, evaluates the blackbox density
            estimate function at those points to output a 1xQ array of 
            density values.
    
        INPUT:
            samples (ndarray) = A QxM matrix where Q is the number of points 
                                at which the kde is being evaluated and M is 
                                the number of parameters.
                                
        OUTPUT:
            dens (ndarray) = A 1xQ array of density values for Q data points.
                               
        HISTORY:
            2018-07-15 - Updated - Ayush Pandhi
        """
        #To correct the type of information from other functions into acceptable input
        #samples = np.array([samples])
        
        #Scaling samples with standard deviation
        samples = (samples - inputs_mean)/inputs_std
        
        #Get the log density for selected samples and apply exponential to get normal probabilities
        log_dens = kde.score_samples(samples)
        dens = np.exp(log_dens)
        
        #Return a 1xQ array of normal probabilities for the selected sample
        return dens
    
    #Return a black box function for sampling
    return input_KDE

# %%
#Generate kde for 6D qdf inputs
kde_gaia_epanechnikov = generate_KDE(gaia_data, 'epanechnikov')

# %%
#Creating sample points for each parameter changing
N = 1000

#Mean of each parameter as a Nx1 object
mean_R = np.ones((N, 1))*np.mean(gaia_data[:,0])
mean_phi = np.ones((N, 1))*np.mean(gaia_data[:,1])
mean_z = np.ones((N, 1))*np.mean(gaia_data[:,2])
mean_vR = np.ones((N, 1))*np.mean(gaia_data[:,3])
mean_vT = np.ones((N, 1))*np.mean(gaia_data[:,4])
mean_vz = np.ones((N, 1))*np.mean(gaia_data[:,5])

#Generating Nx6 sample points for each varying parameter
#For variable R
R_points = np.linspace(min(gaia_data[:,0]), max(gaia_data[:,0]), N)
R_points = R_points.reshape(-1, 1)
sample_R = np.hstack((R_points, mean_phi, mean_z, mean_vR, mean_vT, mean_vz))

#For variable phi
phi_points = np.linspace(min(gaia_data[:,1]), max(gaia_data[:,1]), N)
phi_points = phi_points.reshape(-1, 1)
sample_phi = np.hstack((mean_R, phi_points, mean_z, mean_vR, mean_vT, mean_vz))
                 
#For variable z
z_points = np.linspace(min(gaia_data[:,2]), max(gaia_data[:,2]), N)
z_points = z_points.reshape(-1, 1)
sample_z = np.hstack((mean_R, mean_phi, z_points, mean_vR, mean_vT, mean_vz))
                 
#For variable vR
vR_points = np.linspace(min(gaia_data[:,3]), max(gaia_data[:,3]), N)
vR_points = vR_points.reshape(-1, 1)
sample_vR = np.hstack((mean_R, mean_phi, mean_z, vR_points, mean_vT, mean_vz))

#For variable vT
vT_points = np.linspace(min(gaia_data[:,4]), max(gaia_data[:,4]), N)
vT_points = vT_points.reshape(-1, 1)
sample_vT = np.hstack((mean_R, mean_phi, mean_z, mean_vR, vT_points, mean_vz))
                 
#For variable vz
vz_points = np.linspace(min(gaia_data[:,5]), max(gaia_data[:,5]), N)
vz_points = vz_points.reshape(-1, 1)
sample_vz = np.hstack((mean_R, mean_phi, mean_z, mean_vR, mean_vT, vz_points))

# %%
#Variable R plot
print('Variable R at Scotts bw')
plt.figure(figsize = (10, 8))
Rplot_epanechnikov = kde_gaia_epanechnikov(sample_R)
plt.plot(R_points, Rplot_epanechnikov)
plt.xlabel('Radius (kpc)')
plt.ylabel('Normalized Density')
plt.title('Density Function for Variable R')
plt.savefig('gaia_zscore_cyl_variable_R')
plt.show()
# Out:
# Variable R at Scotts bw

# %%
#Variable phi plot
print('Variable phi at Scotts bw')
plt.figure(figsize = (10, 8))
phiplot_epanechnikov = kde_gaia_epanechnikov(sample_phi)
plt.plot(phi_points, phiplot_epanechnikov)
plt.xlabel('phi (radians)')
plt.ylabel('Normalized Density')
plt.title('Density Function for Variable phi')
plt.savefig('gaia_zscore_cyl_variable_phi')
plt.show()
# Out:
# Variable phi at Scotts bw

# %%
#Variable z plot
print('Variable z at Scotts bw')
plt.figure(figsize = (10, 8))
zplot_epanechnikov = kde_gaia_epanechnikov(sample_z)
plt.plot(z_points, zplot_epanechnikov)
plt.xlabel('z (kpc)')
plt.ylabel('Normalized Density')
plt.title('Density Function for Variable z')
plt.savefig('gaia_zscore_cyl_variable_z')
plt.show()
# Out:
# Variable z at Scotts bw

# %%
#Variable vR plot
print('Variable vR at Scotts bw')
plt.figure(figsize = (10, 8))
vRplot_epanechnikov = kde_gaia_epanechnikov(sample_vR)
plt.plot(vR_points, vRplot_epanechnikov)
plt.xlabel('Radial Velocity (km/s)')
plt.ylabel('Normalized Density')
plt.title('Density Function for Variable vR')
plt.savefig('gaia_zscore_cyl_variable_vR')
plt.show()
# Out:
# Variable vR at Scotts bw

# %%
#Variable vT plot
print('Variable vT at Scotts bw')
plt.figure(figsize = (10, 8))
vTplot_epanechnikov = kde_gaia_epanechnikov(sample_vT)
plt.plot(vT_points, vTplot_epanechnikov)
plt.xlabel('Tangential Velocity (km/s)')
plt.ylabel('Normalized Density')
plt.title('Density Function for Variable vT')
plt.savefig('gaia_zscore_cyl_variable_vT')
plt.show()
# Out:
# Variable vT at Scotts bw

# %%
#Variable vz plot
print('Variable vz at Scotts bw')
plt.figure(figsize = (10, 8))
vzplot_epanechnikov = kde_gaia_epanechnikov(sample_vz)
plt.plot(vz_points, vzplot_epanechnikov)
plt.xlabel('Vertical Velocity (km/s)')
plt.ylabel('Normalized Density')
plt.title('Density Function for Variable vz')
plt.savefig('gaia_zscore_cyl_variable_vz')
plt.show()
# Out:
# Variable vz at Scotts bw

# %%
#For variable vR
vR_points = np.linspace(-250, 350, N)
vR_points = vR_points.reshape(-1, 1)
sample_vR = np.hstack((mean_R, mean_phi, mean_z, vR_points, mean_vT, mean_vz))

#For variable vT
vT_points = np.linspace(-350, 200, N)
vT_points = vT_points.reshape(-1, 1)
sample_vT = np.hstack((mean_R, mean_phi, mean_z, mean_vR, vT_points, mean_vz))
                 
#For variable vz
vz_points = np.linspace(-250, 350, N)
vz_points = vz_points.reshape(-1, 1)
sample_vz = np.hstack((mean_R, mean_phi, mean_z, mean_vR, mean_vT, vz_points))

#Overplotting velocities
plt.figure(figsize = (10, 8))

#Epanechnikov, vR, Scotts
vRplot_epanechnikov = kde_gaia_epanechnikov(sample_vR)
plt.plot(vR_points, vRplot_epanechnikov, label='vR')

#Epanechnikov, vT, Scotts
vTplot_epanechnikov = kde_gaia_epanechnikov(sample_vT)
plt.plot(vT_points, vTplot_epanechnikov, label='vT')

#Epanechnikov, vz, Scotts
vzplot_epanechnikov = kde_gaia_epanechnikov(sample_vz)
plt.plot(vz_points, vzplot_epanechnikov, label='vz')

#Show plot
plt.xlabel('Velocity (km/s)')
plt.ylabel('Normalized Density')
plt.title('Cylindrical Velocity Distributions')
plt.legend()
plt.savefig('gaia_zscore_cyl_velocity_distribution')
plt.show()

# %%
from scipy.integrate import dblquad
import time

#input values for velocities (vR, vT, vz)
v_input = np.linspace(-400, 200, 100)

# -----------------
# Integrate over vR
# -----------------

def kde_gaia_cyl_vR(vT, vz, R, phi, z, vR):
    evaluation = kde_gaia_epanechnikov(np.array([[R, phi, z, vR, vT, vz]]))
    return evaluation

def integrate_over_vR(kde_gaia_epanechnikov, vR): #bounds of vT = [-300, 0], bounds of vz = [-100, 100]
    print ("Evaluating at vR =", vR)
    return dblquad(kde_gaia_cyl_vR, -300, 0, -100, 100, args=([8.3, 3.14, 0., vR]), epsabs=0.001)  # args=(R, phi, z, vR)

vR_output = np.ones([100])


print("With R, phi, z = 8.3, 3.14, 0., integrating over vT from [=300, 0] and vz from [-100, 100].")
print("KDE Evaluations along vR from [-400, 200] over 100 subintervals.")
print()

counter = 0
start_overall = time.time()

for v in np.nditer(v_input):
    counter += 1
    print("Evaluation:", counter)
    start = time.time()
    vR_output[counter - 1], error = integrate_over_vR(kde_gaia_epanechnikov, v)
    print("Value:", vR_output[counter - 1])
    end = time.time()
    print("Time to integrate: "'{}'"s".format(round(end - start, 2)))
    print("Time elapsed: "'{}'" min".format(round((end - start_overall)/60, 2)))
    print()
    
# -----------------
# Integrate over vT
# -----------------

def kde_gaia_cyl_vT(vR, vz, R, phi, z, vT):
    evaluation = kde_gaia_epanechnikov(np.array([[R, phi, z, vR, vT, vz]]))
    return evaluation

def integrate_over_vT(kde_gaia_epanechnikov, vT): #bounds of vR = [-100, 100], bounds of vz = [-100, 100]
    print ("Evaluating at vT =", vT)
    return dblquad(kde_gaia_cyl_vT, -100, 100, -100, 100, args=([8.3, 3.14, 0., vT]), epsabs=0.01)  # args=(R, phi, z, vR)

vT_output = np.ones([100])


print("With R, phi, z = 8.3, 3.14, 0., integrating over vR from [-100, 100] and vz from [-100, 100].")
print("KDE Evaluations along vT from [-400, 200] over 100 subintervals.")
print()

counter = 0
start_overall = time.time()

for v in np.nditer(v_input):
    counter += 1
    print("Evaluation:", counter)
    start = time.time()
    vT_output[counter - 1], error = integrate_over_vT(kde_gaia_epanechnikov, v)
    print("Value:", vT_output[counter - 1])
    end = time.time()
    print("Time to integrate: "'{}'"s".format(round(end - start, 2)))
    print("Time elapsed: "'{}'" min".format(round((end - start_overall)/60, 2)))
    print()
    
# -----------------
# Integrate over vz
# -----------------

def kde_gaia_cyl_vz(vR, vT, R, phi, z, vz):
    evaluation = kde_gaia_epanechnikov(np.array([[R, phi, z, vR, vT, vz]]))
    return evaluation

def integrate_over_vz(kde_gaia_epanechnikov, vz): #bounds of vR = [-100, 100], bounds of vT = [-300, 0]
    print ("Evaluating at vz =", vz)
    return dblquad(kde_gaia_cyl_vz, -100, 100, -300, 0, args=([8.3, 3.14, 0., vz]), epsabs=0.001)  # args=(R, phi, z, vR)

vz_output = np.ones([100])


print("With R, phi, z = 8.3, 3.14, 0., integrating over vR from [-100, 100] and vT from [0, 300].")
print("KDE Evaluations along vz from [-400, 200] over 100 subintervals.")
print()

counter = 0
start_overall = time.time()

for v in np.nditer(v_input):
    counter += 1
    print("Evaluation:", counter)
    start = time.time()
    vz_output[counter - 1], error = integrate_over_vz(kde_gaia_epanechnikov, v)
    print("Value:", vz_output[counter - 1])
    end = time.time()
    print("Time to integrate: "'{}'"s".format(round(end - start, 2)))
    print("Time elapsed: "'{}'" min".format(round((end - start_overall)/60, 2)))
    print()
# Out:
# With R, phi, z = 8.3, 3.14, 0., integrating over vT from [=300, 0] and vz from [-100, 100].
# KDE Evaluations along vR from [-400, 200] over 100 subintervals.
#
# Evaluation: 1
# Evaluating at vR = -400.0
# Value: 2.1398401885441173e-05
# Time to integrate: 0.78s
# Time elapsed: 0.01 min
#
# Evaluation: 2
# Evaluating at vR = -393.93939393939394
# Value: 2.8065615105555137e-05
# Time to integrate: 0.78s
# Time elapsed: 0.03 min
#
# Evaluation: 3
# Evaluating at vR = -387.8787878787879
# Value: 3.581404058391386e-05
# Time to integrate: 0.24s
# Time elapsed: 0.03 min
#
# Evaluation: 4
# Evaluating at vR = -381.8181818181818
# Value: 4.402739699886273e-05
# Time to integrate: 0.72s
# Time elapsed: 0.04 min
#
# Evaluation: 5
# Evaluating at vR = -375.75757575757575
# Value: 5.341931916928351e-05
# Time to integrate: 0.34s
# Time elapsed: 0.05 min
#
# Evaluation: 6
# Evaluating at vR = -369.6969696969697
# Value: 6.392314881799759e-05
# Time to integrate: 0.37s
# Time elapsed: 0.05 min
#
# Evaluation: 7
# Evaluating at vR = -363.6363636363636
# Value: 7.663336344908337e-05
# Time to integrate: 0.38s
# Time elapsed: 0.06 min
#
# Evaluation: 8
# Evaluating at vR = -357.57575757575756
# Value: 9.164593188437398e-05
# Time to integrate: 0.98s
# Time elapsed: 0.08 min
#
# Evaluation: 9
# Evaluating at vR = -351.5151515151515
# Value: 0.00010992548628004316
# Time to integrate: 0.87s
# Time elapsed: 0.09 min
#
# Evaluation: 10
# Evaluating at vR = -345.45454545454544
# Value: 0.000130941854648393
# Time to integrate: 0.35s
# Time elapsed: 0.1 min
#
# Evaluation: 11
# Evaluating at vR = -339.3939393939394
# Value: 0.00015563026117153435
# Time to integrate: 0.95s
# Time elapsed: 0.11 min
#
# Evaluation: 12
# Evaluating at vR = -333.3333333333333
# Value: 0.00018124392241307565
# Time to integrate: 1.08s
# Time elapsed: 0.13 min
#
# Evaluation: 13
# Evaluating at vR = -327.27272727272725
# Value: 0.00020733004726131404
# Time to integrate: 0.99s
# Time elapsed: 0.15 min
#
# Evaluation: 14
# Evaluating at vR = -321.21212121212125
# Value: 0.00023320583999209102
# Time to integrate: 1.26s
# Time elapsed: 0.17 min
#
# Evaluation: 15
# Evaluating at vR = -315.1515151515151
# Value: 0.0002591650350679819
# Time to integrate: 1.19s
# Time elapsed: 0.19 min
#
# Evaluation: 16
# Evaluating at vR = -309.0909090909091
# Value: 0.00028580217709549385
# Time to integrate: 0.3s
# Time elapsed: 0.19 min
#
# Evaluation: 17
# Evaluating at vR = -303.030303030303
# Value: 0.0003110986116135494
# Time to integrate: 0.32s
# Time elapsed: 0.2 min
#
# Evaluation: 18
# Evaluating at vR = -296.969696969697
# Value: 0.0003361136503589588
# Time to integrate: 0.34s
# Time elapsed: 0.2 min
#
# Evaluation: 19
# Evaluating at vR = -290.9090909090909
# Value: 0.00036063228152105104
# Time to integrate: 0.32s
# Time elapsed: 0.21 min
#
# Evaluation: 20
# Evaluating at vR = -284.8484848484849
# Value: 0.00038558266544684903
# Time to integrate: 0.34s
# Time elapsed: 0.22 min
#
# Evaluation: 21
# Evaluating at vR = -278.78787878787875
# Value: 0.00041091855557794766
# Time to integrate: 0.33s
# Time elapsed: 0.22 min
#
# Evaluation: 22
# Evaluating at vR = -272.72727272727275
# Value: 0.0004371096679916931
# Time to integrate: 0.4s
# Time elapsed: 0.23 min
#
# Evaluation: 23
# Evaluating at vR = -266.66666666666663
# Value: 0.00046260295366770855
# Time to integrate: 0.33s
# Time elapsed: 0.23 min
#
# Evaluation: 24
# Evaluating at vR = -260.6060606060606
# Value: 0.00048703400799957394
# Time to integrate: 0.93s
# Time elapsed: 0.25 min
#
# Evaluation: 25
# Evaluating at vR = -254.54545454545456
# Value: 0.0005124525733409256
# Time to integrate: 0.98s
# Time elapsed: 0.26 min
#
# Evaluation: 26
# Evaluating at vR = -248.4848484848485
# Value: 0.0005377926615179517
# Time to integrate: 1.03s
# Time elapsed: 0.28 min
#
# Evaluation: 27
# Evaluating at vR = -242.42424242424244
# Value: 0.000563372397379254
# Time to integrate: 1.04s
# Time elapsed: 0.3 min
#
# Evaluation: 28
# Evaluating at vR = -236.36363636363637
# Value: 0.0005909457325299801
# Time to integrate: 1.07s
# Time elapsed: 0.32 min
#
# Evaluation: 29
# Evaluating at vR = -230.3030303030303
# Value: 0.0006207703611885525
# Time to integrate: 0.35s
# Time elapsed: 0.32 min
#
# Evaluation: 30
# Evaluating at vR = -224.24242424242425
# Value: 0.0006552918537996589
# Time to integrate: 0.38s
# Time elapsed: 0.33 min
#
# Evaluation: 31
# Evaluating at vR = -218.1818181818182
# Value: 0.0006938251830427635
# Time to integrate: 0.39s
# Time elapsed: 0.34 min
#
# Evaluation: 32
# Evaluating at vR = -212.12121212121212
# Value: 0.0007366660785013159
# Time to integrate: 0.38s
# Time elapsed: 0.34 min
#
# Evaluation: 33
# Evaluating at vR = -206.06060606060606
# Value: 0.0007861238153611808
# Time to integrate: 0.39s
# Time elapsed: 0.35 min
#
# Evaluation: 34
# Evaluating at vR = -200.0
# Value: 0.0008425287156917798
# Time to integrate: 0.38s
# Time elapsed: 0.35 min
#
# Evaluation: 35
# Evaluating at vR = -193.93939393939394
# Value: 0.0009052044326184005
# Time to integrate: 0.36s
# Time elapsed: 0.36 min
#
# Evaluation: 36
# Evaluating at vR = -187.87878787878788
# Value: 0.000973456862889583
# Time to integrate: 0.94s
# Time elapsed: 0.38 min
#
# Evaluation: 37
# Evaluating at vR = -181.8181818181818
# Value: 0.0010491436703529522
# Time to integrate: 0.99s
# Time elapsed: 0.39 min
#
# Evaluation: 38
# Evaluating at vR = -175.75757575757575
# Value: 0.0011331100437144478
# Time to integrate: 1.02s
# Time elapsed: 0.41 min
#
# Evaluation: 39
# Evaluating at vR = -169.6969696969697
# Value: 0.001223207578120586
# Time to integrate: 0.99s
# Time elapsed: 0.43 min
#
# Evaluation: 40
# Evaluating at vR = -163.63636363636363
# Value: 0.0013193636533402157
# Time to integrate: 0.94s
# Time elapsed: 0.44 min
#
# Evaluation: 41
# Evaluating at vR = -157.57575757575756
# Value: 0.0014237410805641954
# Time to integrate: 0.31s
# Time elapsed: 0.45 min
#
# Evaluation: 42
# Evaluating at vR = -151.51515151515153
# Value: 0.0015356012382047553
# Time to integrate: 0.31s
# Time elapsed: 0.45 min
#
# Evaluation: 43
# Evaluating at vR = -145.45454545454547
# Value: 0.0016563657937880077
# Time to integrate: 0.35s
# Time elapsed: 0.46 min
#
# Evaluation: 44
# Evaluating at vR = -139.39393939393938
# Value: 0.0017858892555067368
# Time to integrate: 0.32s
# Time elapsed: 0.46 min
#
# Evaluation: 45
# Evaluating at vR = -133.33333333333331
# Value: 0.0019237488094946877
# Time to integrate: 0.28s
# Time elapsed: 0.47 min
#
# Evaluation: 46
# Evaluating at vR = -127.27272727272725
# Value: 0.002073565838099645
# Time to integrate: 0.27s
# Time elapsed: 0.47 min
#
# Evaluation: 47
# Evaluating at vR = -121.21212121212119
# Value: 0.002236323954386053
# Time to integrate: 0.29s
# Time elapsed: 0.48 min
#
# Evaluation: 48
# Evaluating at vR = -115.15151515151513
# Value: 0.0024117118418742526
# Time to integrate: 0.24s
# Time elapsed: 0.48 min
#
# Evaluation: 49
# Evaluating at vR = -109.09090909090912
# Value: 0.0025991293963239536
# Time to integrate: 0.3s
# Time elapsed: 0.49 min
#
# Evaluation: 50
# Evaluating at vR = -103.03030303030306
# Value: 0.002800041329158226
# Time to integrate: 0.3s
# Time elapsed: 0.49 min
#
# Evaluation: 51
# Evaluating at vR = -96.969696969697
# Value: 0.0030202647352281613
# Time to integrate: 0.81s
# Time elapsed: 0.51 min
#
# Evaluation: 52
# Evaluating at vR = -90.90909090909093
# Value: 0.0032562633794213803
# Time to integrate: 0.84s
# Time elapsed: 0.52 min
#
# Evaluation: 53
# Evaluating at vR = -84.84848484848487
# Value: 0.003505755794823711
# Time to integrate: 0.29s
# Time elapsed: 0.52 min
#
# Evaluation: 54
# Evaluating at vR = -78.78787878787881
# Value: 0.0037691996519442377
# Time to integrate: 0.36s
# Time elapsed: 0.53 min
#
# Evaluation: 55
# Evaluating at vR = -72.72727272727275
# Value: 0.004041157315596335
# Time to integrate: 0.38s
# Time elapsed: 0.54 min
#
# Evaluation: 56
# Evaluating at vR = -66.66666666666669
# Value: 0.004316046249309879
# Time to integrate: 0.32s
# Time elapsed: 0.54 min
#
# Evaluation: 57
# Evaluating at vR = -60.60606060606062
# Value: 0.004589330704015934
# Time to integrate: 0.4s
# Time elapsed: 0.55 min
#
# Evaluation: 58
# Evaluating at vR = -54.54545454545456
# Value: 0.00485656666975311
# Time to integrate: 0.41s
# Time elapsed: 0.56 min
#
# Evaluation: 59
# Evaluating at vR = -48.4848484848485
# Value: 0.005112413874211444
# Time to integrate: 0.36s
# Time elapsed: 0.56 min
#
# Evaluation: 60
# Evaluating at vR = -42.424242424242436
# Value: 0.005350488437649968
# Time to integrate: 0.37s
# Time elapsed: 0.57 min
#
# Evaluation: 61
# Evaluating at vR = -36.363636363636374
# Value: 0.005568138231589725
# Time to integrate: 0.39s
# Time elapsed: 0.57 min
#
# Evaluation: 62
# Evaluating at vR = -30.30303030303031
# Value: 0.005764825973995736
# Time to integrate: 0.35s
# Time elapsed: 0.58 min
#
# Evaluation: 63
# Evaluating at vR = -24.24242424242425
# Value: 0.00593479748910938
# Time to integrate: 0.38s
# Time elapsed: 0.59 min
#
# Evaluation: 64
# Evaluating at vR = -18.181818181818187
# Value: 0.006072198275612159
# Time to integrate: 0.41s
# Time elapsed: 0.59 min
#
# Evaluation: 65
# Evaluating at vR = -12.121212121212125
# Value: 0.006169381464879254
# Time to integrate: 1.07s
# Time elapsed: 0.61 min
#
# Evaluation: 66
# Evaluating at vR = -6.060606060606062
# Value: 0.006226544661979869
# Time to integrate: 1.28s
# Time elapsed: 0.63 min
#
# Evaluation: 67
# Evaluating at vR = 0.0
# Value: 0.0062385250060384275
# Time to integrate: 1.22s
# Time elapsed: 0.65 min
#
# Evaluation: 68
# Evaluating at vR = 6.060606060606062
# Value: 0.006206102441275319
# Time to integrate: 1.12s
# Time elapsed: 0.67 min
#
# Evaluation: 69
# Evaluating at vR = 12.121212121212125
# Value: 0.006130813322707938
# Time to integrate: 1.07s
# Time elapsed: 0.69 min
#
# Evaluation: 70
# Evaluating at vR = 18.181818181818187
# Value: 0.006016831651166235
# Time to integrate: 1.11s
# Time elapsed: 0.71 min
#
# Evaluation: 71
# Evaluating at vR = 24.24242424242425
# Value: 0.005864437079108285
# Time to integrate: 1.16s
# Time elapsed: 0.73 min
#
# Evaluation: 72
# Evaluating at vR = 30.30303030303031
# Value: 0.005678892150496631
# Time to integrate: 1.14s
# Time elapsed: 0.75 min
#
# Evaluation: 73
# Evaluating at vR = 36.363636363636374
# Value: 0.005471245936693434
# Time to integrate: 1.15s
# Time elapsed: 0.76 min
#
# Evaluation: 74
# Evaluating at vR = 42.424242424242436
# Value: 0.005247068669507672
# Time to integrate: 1.17s
# Time elapsed: 0.78 min
#
# Evaluation: 75
# Evaluating at vR = 48.4848484848485
# Value: 0.005010540942033332
# Time to integrate: 1.42s
# Time elapsed: 0.81 min
#
# Evaluation: 76
# Evaluating at vR = 54.54545454545456
# Value: 0.004764328568697565
# Time to integrate: 1.32s
# Time elapsed: 0.83 min
#
# Evaluation: 77
# Evaluating at vR = 60.60606060606062
# Value: 0.004513378965459096
# Time to integrate: 1.74s
# Time elapsed: 0.86 min
#
# Evaluation: 78
# Evaluating at vR = 66.66666666666669
# Value: 0.004259688391388274
# Time to integrate: 1.67s
# Time elapsed: 0.89 min
#
# Evaluation: 79
# Evaluating at vR = 72.72727272727275
# Value: 0.004005255904427102
# Time to integrate: 0.57s
# Time elapsed: 0.9 min
#
# Evaluation: 80
# Evaluating at vR = 78.78787878787881
# Value: 0.003753540079043412
# Time to integrate: 0.51s
# Time elapsed: 0.91 min
#
# Evaluation: 81
# Evaluating at vR = 84.84848484848487
# Value: 0.003504901893116126
# Time to integrate: 0.62s
# Time elapsed: 0.92 min
#
# Evaluation: 82
# Evaluating at vR = 90.90909090909088
# Value: 0.003262098352726517
# Time to integrate: 0.78s
# Time elapsed: 0.93 min
#
# Evaluation: 83
# Evaluating at vR = 96.96969696969694
# Value: 0.0030235129477847273
# Time to integrate: 0.8s
# Time elapsed: 0.94 min
#
# Evaluation: 84
# Evaluating at vR = 103.030303030303
# Value: 0.002793035584576901
# Time to integrate: 0.49s
# Time elapsed: 0.95 min
#
# Evaluation: 85
# Evaluating at vR = 109.09090909090907
# Value: 0.0025698185729432343
# Time to integrate: 0.45s
# Time elapsed: 0.96 min
#
# Evaluation: 86
# Evaluating at vR = 115.15151515151513
# Value: 0.0023535925098432846
# Time to integrate: 0.46s
# Time elapsed: 0.97 min
#
# Evaluation: 87
# Evaluating at vR = 121.21212121212125
# Value: 0.0021474321936591364
# Time to integrate: 0.38s
# Time elapsed: 0.97 min
#
# Evaluation: 88
# Evaluating at vR = 127.27272727272725
# Value: 0.0019514031165985169
# Time to integrate: 0.36s
# Time elapsed: 0.98 min
#
# Evaluation: 89
# Evaluating at vR = 133.33333333333337
# Value: 0.0017690152388628703
# Time to integrate: 0.41s
# Time elapsed: 0.98 min
#
# Evaluation: 90
# Evaluating at vR = 139.39393939393938
# Value: 0.001598885536278969
# Time to integrate: 0.41s
# Time elapsed: 0.99 min
#
# Evaluation: 91
# Evaluating at vR = 145.4545454545455
# Value: 0.0014430134435571467
# Time to integrate: 0.37s
# Time elapsed: 1.0 min
#
# Evaluation: 92
# Evaluating at vR = 151.5151515151515
# Value: 0.0013019230923628994
# Time to integrate: 0.4s
# Time elapsed: 1.0 min
#
# Evaluation: 93
# Evaluating at vR = 157.57575757575762
# Value: 0.0011740151338263311
# Time to integrate: 0.47s
# Time elapsed: 1.01 min
#
# Evaluation: 94
# Evaluating at vR = 163.63636363636363
# Value: 0.001059907140300004
# Time to integrate: 0.43s
# Time elapsed: 1.02 min
#
# Evaluation: 95
# Evaluating at vR = 169.69696969696975
# Value: 0.0009592628404771476
# Time to integrate: 0.41s
# Time elapsed: 1.03 min
#
# Evaluation: 96
# Evaluating at vR = 175.75757575757575
# Value: 0.0008682675821426943
# Time to integrate: 0.43s
# Time elapsed: 1.03 min
#
# Evaluation: 97
# Evaluating at vR = 181.81818181818176
# Value: 0.0007892117039310126
# Time to integrate: 0.49s
# Time elapsed: 1.04 min
#
# Evaluation: 98
# Evaluating at vR = 187.87878787878788
# Value: 0.0007225101503606283
# Time to integrate: 0.49s
# Time elapsed: 1.05 min
#
# Evaluation: 99
# Evaluating at vR = 193.93939393939388
# Value: 0.0006688386400561907
# Time to integrate: 0.52s
# Time elapsed: 1.06 min
#
# Evaluation: 100
# Evaluating at vR = 200.0
# Value: 0.000624799939486806
# Time to integrate: 1.32s
# Time elapsed: 1.08 min
#
# With R, phi, z = 8.3, 3.14, 0., integrating over vR from [-100, 100] and vz from [-100, 100].
# KDE Evaluations along vT from [-400, 200] over 100 subintervals.
#
# Evaluation: 1
# Evaluating at vT = -400.0
# Value: 4.813522758299814e-05
# Time to integrate: 0.46s
# Time elapsed: 0.01 min
#
# Evaluation: 2
# Evaluating at vT = -393.93939393939394
# Value: 4.786666663424998e-05
# Time to integrate: 0.45s
# Time elapsed: 0.02 min
#
# Evaluation: 3
# Evaluating at vT = -387.8787878787879
# Value: 4.65091807638009e-05
# Time to integrate: 1.46s
# Time elapsed: 0.04 min
#
# Evaluation: 4
# Evaluating at vT = -381.8181818181818
# Value: 4.5248498529450365e-05
# Time to integrate: 1.26s
# Time elapsed: 0.06 min
#
# Evaluation: 5
# Evaluating at vT = -375.75757575757575
# Value: 4.4848809662445794e-05
# Time to integrate: 0.38s
# Time elapsed: 0.07 min
#
# Evaluation: 6
# Evaluating at vT = -369.6969696969697
# Value: 4.5597589184957296e-05
# Time to integrate: 0.44s
# Time elapsed: 0.07 min
#
# Evaluation: 7
# Evaluating at vT = -363.6363636363636
# Value: 4.720284725074615e-05
# Time to integrate: 0.49s
# Time elapsed: 0.08 min
#
# Evaluation: 8
# Evaluating at vT = -357.57575757575756
# Value: 5.0715861122836874e-05
# Time to integrate: 1.18s
# Time elapsed: 0.1 min
#
# Evaluation: 9
# Evaluating at vT = -351.5151515151515
# Value: 6.150994431849831e-05
# Time to integrate: 1.18s
# Time elapsed: 0.12 min
#
# Evaluation: 10
# Evaluating at vT = -345.45454545454544
# Value: 8.720891423344688e-05
# Time to integrate: 1.37s
# Time elapsed: 0.14 min
#
# Evaluation: 11
# Evaluating at vT = -339.3939393939394
# Value: 0.00015329068455646768
# Time to integrate: 1.75s
# Time elapsed: 0.17 min
#
# Evaluation: 12
# Evaluating at vT = -333.3333333333333
# Value: 0.00041477640893589616
# Time to integrate: 2.19s
# Time elapsed: 0.21 min
#
# Evaluation: 13
# Evaluating at vT = -327.27272727272725
# Value: 0.001414662611871602
# Time to integrate: 1.87s
# Time elapsed: 0.24 min
#
# Evaluation: 14
# Evaluating at vT = -321.21212121212125
# Value: 0.004133204778599489
# Time to integrate: 0.78s
# Time elapsed: 0.25 min
#
# Evaluation: 15
# Evaluating at vT = -315.1515151515151
# Value: 0.0103020111351592
# Time to integrate: 0.85s
# Time elapsed: 0.27 min
#
# Evaluation: 16
# Evaluating at vT = -309.0909090909091
# Value: 0.02255039170107265
# Time to integrate: 1.07s
# Time elapsed: 0.29 min
#
# Evaluation: 17
# Evaluating at vT = -303.030303030303
# Value: 0.04547482505215068
# Time to integrate: 6.59s
# Time elapsed: 0.4 min
#
# Evaluation: 18
# Evaluating at vT = -296.969696969697
# Value: 0.09121776873583023
# Time to integrate: 10.62s
# Time elapsed: 0.57 min
#
# Evaluation: 19
# Evaluating at vT = -290.9090909090909
# Value: 0.18224078101362134
# Time to integrate: 14.95s
# Time elapsed: 0.82 min
#
# Evaluation: 20
# Evaluating at vT = -284.8484848484849
# Value: 0.3463856748572418
# Time to integrate: 21.94s
# Time elapsed: 1.19 min
#
# Evaluation: 21
# Evaluating at vT = -278.78787878787875
# Value: 0.6114117944399527
# Time to integrate: 6.46s
# Time elapsed: 1.3 min
#
# Evaluation: 22
# Evaluating at vT = -272.72727272727275
# Value: 1.0004980914271646
# Time to integrate: 40.27s
# Time elapsed: 1.97 min
#
# Evaluation: 23
# Evaluating at vT = -266.66666666666663
# Value: 1.5288456523436753
# Time to integrate: 47.83s
# Time elapsed: 2.76 min
#
# Evaluation: 24
# Evaluating at vT = -260.6060606060606
# Value: 2.1935673103804083
# Time to integrate: 62.9s
# Time elapsed: 3.81 min
#
# Evaluation: 25
# Evaluating at vT = -254.54545454545456
# Value: 2.965970438143338
# Time to integrate: 77.36s
# Time elapsed: 5.1 min
#
# Evaluation: 26
# Evaluating at vT = -248.4848484848485
# Value: 3.795674805521621
# Time to integrate: 75.92s
# Time elapsed: 6.37 min
#
# Evaluation: 27
# Evaluating at vT = -242.42424242424244
# Value: 4.620616769941504
# Time to integrate: 84.6s
# Time elapsed: 7.78 min
#
# Evaluation: 28
# Evaluating at vT = -236.36363636363637
# Value: 5.377221851394925
# Time to integrate: 90.85s
# Time elapsed: 9.29 min
#
# Evaluation: 29
# Evaluating at vT = -230.3030303030303
# Value: 6.0047617723622295
# Time to integrate: 96.22s
# Time elapsed: 10.89 min
#
# Evaluation: 30
# Evaluating at vT = -224.24242424242425
# Value: 6.451107112156838
# Time to integrate: 100.44s
# Time elapsed: 12.57 min
#
# Evaluation: 31
# Evaluating at vT = -218.1818181818182
# Value: 6.679227412444487
# Time to integrate: 101.81s
# Time elapsed: 14.27 min
#
# Evaluation: 32
# Evaluating at vT = -212.12121212121212
# Value: 6.671048933443014
# Time to integrate: 103.3s
# Time elapsed: 15.99 min
#
# Evaluation: 33
# Evaluating at vT = -206.06060606060606
# Value: 6.429668214237792
# Time to integrate: 101.53s
# Time elapsed: 17.68 min
#
# Evaluation: 34
# Evaluating at vT = -200.0
# Value: 5.979956673269405
# Time to integrate: 99.1s
# Time elapsed: 19.33 min
#
# Evaluation: 35
# Evaluating at vT = -193.93939393939394
# Value: 5.366740470018465
# Time to integrate: 109.78s
# Time elapsed: 21.16 min
#
# Evaluation: 36
# Evaluating at vT = -187.87878787878788
# Value: 4.649827738983873
# Time to integrate: 113.6s
# Time elapsed: 23.05 min
#
# Evaluation: 37
# Evaluating at vT = -181.8181818181818
# Value: 3.895415023180213
# Time to integrate: 94.74s
# Time elapsed: 24.63 min
#
# Evaluation: 38
# Evaluating at vT = -175.75757575757575
# Value: 3.1632634460738887
# Time to integrate: 85.6s
# Time elapsed: 26.06 min
#
# Evaluation: 39
# Evaluating at vT = -169.6969696969697
# Value: 2.4972637459832225
# Time to integrate: 76.36s
# Time elapsed: 27.33 min
#
# Evaluation: 40
# Evaluating at vT = -163.63636363636363
# Value: 1.9255609825366549
# Time to integrate: 14.88s
# Time elapsed: 27.58 min
#
# Evaluation: 41
# Evaluating at vT = -157.57575757575756
# Value: 1.459853936058872
# Time to integrate: 53.76s
# Time elapsed: 28.48 min
#
# Evaluation: 42
# Evaluating at vT = -151.51515151515153
# Value: 1.0956022959916711
# Time to integrate: 44.15s
# Time elapsed: 29.21 min
#
# Evaluation: 43
# Evaluating at vT = -145.45454545454547
# Value: 0.8153552218334226
# Time to integrate: 8.3s
# Time elapsed: 29.35 min
#
# Evaluation: 44
# Evaluating at vT = -139.39393939393938
# Value: 0.5984000334786312
# Time to integrate: 6.13s
# Time elapsed: 29.45 min
#
# Evaluation: 45
# Evaluating at vT = -133.33333333333331
# Value: 0.43207151081967154
# Time to integrate: 4.93s
# Time elapsed: 29.53 min
#
# Evaluation: 46
# Evaluating at vT = -127.27272727272725
# Value: 0.3086242148138979
# Time to integrate: 4.55s
# Time elapsed: 29.61 min
#
# Evaluation: 47
# Evaluating at vT = -121.21212121212119
# Value: 0.2201467772364728
# Time to integrate: 3.55s
# Time elapsed: 29.67 min
#
# Evaluation: 48
# Evaluating at vT = -115.15151515151513
# Value: 0.15752955519296288
# Time to integrate: 2.26s
# Time elapsed: 29.71 min
#
# Evaluation: 49
# Evaluating at vT = -109.09090909090912
# Value: 0.11295199492384257
# Time to integrate: 1.88s
# Time elapsed: 29.74 min
#
# Evaluation: 50
# Evaluating at vT = -103.03030303030306
# Value: 0.08145475358186074
# Time to integrate: 1.61s
# Time elapsed: 29.77 min
#
# Evaluation: 51
# Evaluating at vT = -96.969696969697
# Value: 0.05919664568909
# Time to integrate: 1.27s
# Time elapsed: 29.79 min
#
# Evaluation: 52
# Evaluating at vT = -90.90909090909093
# Value: 0.04331880079062643
# Time to integrate: 0.94s
# Time elapsed: 29.8 min
#
# Evaluation: 53
# Evaluating at vT = -84.84848484848487
# Value: 0.03190618843923595
# Time to integrate: 0.71s
# Time elapsed: 29.81 min
#
# Evaluation: 54
# Evaluating at vT = -78.78787878787881
# Value: 0.023815462441353057
# Time to integrate: 0.68s
# Time elapsed: 29.83 min
#
# Evaluation: 55
# Evaluating at vT = -72.72727272727275
# Value: 0.01823126853108949
# Time to integrate: 0.66s
# Time elapsed: 29.84 min
#
# Evaluation: 56
# Evaluating at vT = -66.66666666666669
# Value: 0.014381275634615975
# Time to integrate: 0.58s
# Time elapsed: 29.85 min
#
# Evaluation: 57
# Evaluating at vT = -60.60606060606062
# Value: 0.011681960213444234
# Time to integrate: 0.56s
# Time elapsed: 29.86 min
#
# Evaluation: 58
# Evaluating at vT = -54.54545454545456
# Value: 0.009712454088334072
# Time to integrate: 0.61s
# Time elapsed: 29.87 min
#
# Evaluation: 59
# Evaluating at vT = -48.4848484848485
# Value: 0.008225652060013945
# Time to integrate: 0.61s
# Time elapsed: 29.88 min
#
# Evaluation: 60
# Evaluating at vT = -42.424242424242436
# Value: 0.007074871049595726
# Time to integrate: 0.55s
# Time elapsed: 29.88 min
#
# Evaluation: 61
# Evaluating at vT = -36.363636363636374
# Value: 0.0061776838915116265
# Time to integrate: 0.51s
# Time elapsed: 29.89 min
#
# Evaluation: 62
# Evaluating at vT = -30.30303030303031
# Value: 0.005460639994796014
# Time to integrate: 0.6s
# Time elapsed: 29.9 min
#
# Evaluation: 63
# Evaluating at vT = -24.24242424242425
# Value: 0.00486619755178732
# Time to integrate: 0.6s
# Time elapsed: 29.91 min
#
# Evaluation: 64
# Evaluating at vT = -18.181818181818187
# Value: 0.004368397868160989
# Time to integrate: 0.59s
# Time elapsed: 29.92 min
#
# Evaluation: 65
# Evaluating at vT = -12.121212121212125
# Value: 0.003948060691367872
# Time to integrate: 0.61s
# Time elapsed: 29.93 min
#
# Evaluation: 66
# Evaluating at vT = -6.060606060606062
# Value: 0.003584172670887704
# Time to integrate: 0.55s
# Time elapsed: 29.94 min
#
# Evaluation: 67
# Evaluating at vT = 0.0
# Value: 0.0032638728782659254
# Time to integrate: 0.63s
# Time elapsed: 29.95 min
#
# Evaluation: 68
# Evaluating at vT = 6.060606060606062
# Value: 0.0029806941407661135
# Time to integrate: 0.5s
# Time elapsed: 29.96 min
#
# Evaluation: 69
# Evaluating at vT = 12.121212121212125
# Value: 0.0027249542336245753
# Time to integrate: 0.54s
# Time elapsed: 29.97 min
#
# Evaluation: 70
# Evaluating at vT = 18.181818181818187
# Value: 0.002496550661290216
# Time to integrate: 0.48s
# Time elapsed: 29.98 min
#
# Evaluation: 71
# Evaluating at vT = 24.24242424242425
# Value: 0.0022938535841950463
# Time to integrate: 0.53s
# Time elapsed: 29.99 min
#
# Evaluation: 72
# Evaluating at vT = 30.30303030303031
# Value: 0.0021076535251404824
# Time to integrate: 0.57s
# Time elapsed: 30.0 min
#
# Evaluation: 73
# Evaluating at vT = 36.363636363636374
# Value: 0.0019302428742394692
# Time to integrate: 0.48s
# Time elapsed: 30.0 min
#
# Evaluation: 74
# Evaluating at vT = 42.424242424242436
# Value: 0.0017571489408222006
# Time to integrate: 0.46s
# Time elapsed: 30.01 min
#
# Evaluation: 75
# Evaluating at vT = 48.4848484848485
# Value: 0.0015969748986848452
# Time to integrate: 0.52s
# Time elapsed: 30.02 min
#
# Evaluation: 76
# Evaluating at vT = 54.54545454545456
# Value: 0.0014489406026117534
# Time to integrate: 0.47s
# Time elapsed: 30.03 min
#
# Evaluation: 77
# Evaluating at vT = 60.60606060606062
# Value: 0.001313894871237551
# Time to integrate: 0.49s
# Time elapsed: 30.04 min
#
# Evaluation: 78
# Evaluating at vT = 66.66666666666669
# Value: 0.0011905080031916347
# Time to integrate: 0.57s
# Time elapsed: 30.05 min
#
# Evaluation: 79
# Evaluating at vT = 72.72727272727275
# Value: 0.0010782715212380564
# Time to integrate: 0.54s
# Time elapsed: 30.06 min
#
# Evaluation: 80
# Evaluating at vT = 78.78787878787881
# Value: 0.0009793695121797625
# Time to integrate: 0.57s
# Time elapsed: 30.06 min
#
# Evaluation: 81
# Evaluating at vT = 84.84848484848487
# Value: 0.0008957081245533731
# Time to integrate: 0.52s
# Time elapsed: 30.07 min
#
# Evaluation: 82
# Evaluating at vT = 90.90909090909088
# Value: 0.0008283239273805146
# Time to integrate: 0.6s
# Time elapsed: 30.08 min
#
# Evaluation: 83
# Evaluating at vT = 96.96969696969694
# Value: 0.0007748619417989467
# Time to integrate: 0.53s
# Time elapsed: 30.09 min
#
# Evaluation: 84
# Evaluating at vT = 103.030303030303
# Value: 0.0007272058392511441
# Time to integrate: 0.53s
# Time elapsed: 30.1 min
#
# Evaluation: 85
# Evaluating at vT = 109.09090909090907
# Value: 0.0006835788195863734
# Time to integrate: 0.59s
# Time elapsed: 30.11 min
#
# Evaluation: 86
# Evaluating at vT = 115.15151515151513
# Value: 0.0006402789196801798
# Time to integrate: 0.48s
# Time elapsed: 30.12 min
#
# Evaluation: 87
# Evaluating at vT = 121.21212121212125
# Value: 0.00059628839587333
# Time to integrate: 0.45s
# Time elapsed: 30.13 min
#
# Evaluation: 88
# Evaluating at vT = 127.27272727272725
# Value: 0.0005500181068614841
# Time to integrate: 0.46s
# Time elapsed: 30.13 min
#
# Evaluation: 89
# Evaluating at vT = 133.33333333333337
# Value: 0.0004983316245235954
# Time to integrate: 0.55s
# Time elapsed: 30.14 min
#
# Evaluation: 90
# Evaluating at vT = 139.39393939393938
# Value: 0.0004429452511712197
# Time to integrate: 0.56s
# Time elapsed: 30.15 min
#
# Evaluation: 91
# Evaluating at vT = 145.4545454545455
# Value: 0.0003855762254451339
# Time to integrate: 0.64s
# Time elapsed: 30.16 min
#
# Evaluation: 92
# Evaluating at vT = 151.5151515151515
# Value: 0.00032946948914077203
# Time to integrate: 0.48s
# Time elapsed: 30.17 min
#
# Evaluation: 93
# Evaluating at vT = 157.57575757575762
# Value: 0.00027913708860616526
# Time to integrate: 1.83s
# Time elapsed: 30.2 min
#
# Evaluation: 94
# Evaluating at vT = 163.63636363636363
# Value: 0.00023470235181733987
# Time to integrate: 0.61s
# Time elapsed: 30.21 min
#
# Evaluation: 95
# Evaluating at vT = 169.69696969696975
# Value: 0.00019571499004039232
# Time to integrate: 0.58s
# Time elapsed: 30.22 min
#
# Evaluation: 96
# Evaluating at vT = 175.75757575757575
# Value: 0.0001623246687557675
# Time to integrate: 1.47s
# Time elapsed: 30.25 min
#
# Evaluation: 97
# Evaluating at vT = 181.81818181818176
# Value: 0.00013256390429080864
# Time to integrate: 1.76s
# Time elapsed: 30.28 min
#
# Evaluation: 98
# Evaluating at vT = 187.87878787878788
# Value: 0.00010529190439009998
# Time to integrate: 2.11s
# Time elapsed: 30.31 min
#
# Evaluation: 99
# Evaluating at vT = 193.93939393939388
# Value: 8.285097410261473e-05
# Time to integrate: 0.6s
# Time elapsed: 30.32 min
#
# Evaluation: 100
# Evaluating at vT = 200.0
# Value: 6.53764975124082e-05
# Time to integrate: 1.73s
# Time elapsed: 30.35 min
#
# With R, phi, z = 8.3, 3.14, 0., integrating over vR from [-100, 100] and vT from [0, 300].
# KDE Evaluations along vz from [-400, 200] over 100 subintervals.
#
# Evaluation: 1
# Evaluating at vz = -400.0
# Value: 7.393344153565141e-06
# Time to integrate: 0.76s
# Time elapsed: 0.01 min
#
# Evaluation: 2
# Evaluating at vz = -393.93939393939394
# Value: 7.909138361160126e-06
# Time to integrate: 0.78s
# Time elapsed: 0.03 min
#
# Evaluation: 3
# Evaluating at vz = -387.8787878787879
# Value: 7.679354220856132e-06
# Time to integrate: 0.74s
# Time elapsed: 0.04 min
#
# Evaluation: 4
# Evaluating at vz = -381.8181818181818
# Value: 6.718117989168531e-06
# Time to integrate: 0.81s
# Time elapsed: 0.05 min
#
# Evaluation: 5
# Evaluating at vz = -375.75757575757575
# Value: 5.115209083902034e-06
# Time to integrate: 0.88s
# Time elapsed: 0.07 min
#
# Evaluation: 6
# Evaluating at vz = -369.6969696969697
# Value: 3.1740477732367893e-06
# Time to integrate: 0.83s
# Time elapsed: 0.08 min
#
# Evaluation: 7
# Evaluating at vz = -363.6363636363636
# Value: 1.2800216055284682e-06
# Time to integrate: 0.82s
# Time elapsed: 0.09 min
#
# Evaluation: 8
# Evaluating at vz = -357.57575757575756
# Value: 8.1254853729802e-08
# Time to integrate: 0.62s
# Time elapsed: 0.1 min
#
# Evaluation: 9
# Evaluating at vz = -351.5151515151515
# Value: 9.78654972371151e-19
# Time to integrate: 0.74s
# Time elapsed: 0.12 min
#
# Evaluation: 10
# Evaluating at vz = -345.45454545454544
# Value: 1.2322777105411595e-18
# Time to integrate: 0.76s
# Time elapsed: 0.13 min
#
# Evaluation: 11
# Evaluating at vz = -339.3939393939394
# Value: 8.703739772337354e-19
# Time to integrate: 0.76s
# Time elapsed: 0.14 min
#
# Evaluation: 12
# Evaluating at vz = -333.3333333333333
# Value: 1.6918728121055206e-16
# Time to integrate: 1.54s
# Time elapsed: 0.17 min
#
# Evaluation: 13
# Evaluating at vz = -327.27272727272725
# Value: 5.681156008997479e-16
# Time to integrate: 1.62s
# Time elapsed: 0.19 min
#
# Evaluation: 14
# Evaluating at vz = -321.21212121212125
# Value: 3.0647559514293987e-09
# Time to integrate: 1.54s
# Time elapsed: 0.22 min
#
# Evaluation: 15
# Evaluating at vz = -315.1515151515151
# Value: 9.197116462540716e-08
# Time to integrate: 1.54s
# Time elapsed: 0.25 min
#
# Evaluation: 16
# Evaluating at vz = -309.0909090909091
# Value: 4.3815192558086844e-07
# Time to integrate: 1.57s
# Time elapsed: 0.27 min
#
# Evaluation: 17
# Evaluating at vz = -303.030303030303
# Value: 9.996002561131727e-07
# Time to integrate: 1.6s
# Time elapsed: 0.3 min
#
# Evaluation: 18
# Evaluating at vz = -296.969696969697
# Value: 1.7516166200062916e-06
# Time to integrate: 1.64s
# Time elapsed: 0.33 min
#
# Evaluation: 19
# Evaluating at vz = -290.9090909090909
# Value: 2.7007223455756892e-06
# Time to integrate: 1.49s
# Time elapsed: 0.35 min
#
# Evaluation: 20
# Evaluating at vz = -284.8484848484849
# Value: 5.523447406682096e-06
# Time to integrate: 1.53s
# Time elapsed: 0.38 min
#
# Evaluation: 21
# Evaluating at vz = -278.78787878787875
# Value: 1.1233653895393265e-05
# Time to integrate: 1.35s
# Time elapsed: 0.4 min
#
# Evaluation: 22
# Evaluating at vz = -272.72727272727275
# Value: 1.8367035887541334e-05
# Time to integrate: 1.48s
# Time elapsed: 0.42 min
#
# Evaluation: 23
# Evaluating at vz = -266.66666666666663
# Value: 2.5245380357298486e-05
# Time to integrate: 1.27s
# Time elapsed: 0.44 min
#
# Evaluation: 24
# Evaluating at vz = -260.6060606060606
# Value: 3.061918570616115e-05
# Time to integrate: 0.49s
# Time elapsed: 0.45 min
#
# Evaluation: 25
# Evaluating at vz = -254.54545454545456
# Value: 3.401150661178556e-05
# Time to integrate: 1.48s
# Time elapsed: 0.48 min
#
# Evaluation: 26
# Evaluating at vz = -248.4848484848485
# Value: 3.503521873546518e-05
# Time to integrate: 0.5s
# Time elapsed: 0.49 min
#
# Evaluation: 27
# Evaluating at vz = -242.42424242424244
# Value: 3.434395868650282e-05
# Time to integrate: 0.49s
# Time elapsed: 0.49 min
#
# Evaluation: 28
# Evaluating at vz = -236.36363636363637
# Value: 3.308681678212506e-05
# Time to integrate: 0.52s
# Time elapsed: 0.5 min
#
# Evaluation: 29
# Evaluating at vz = -230.3030303030303
# Value: 3.286519042179716e-05
# Time to integrate: 0.47s
# Time elapsed: 0.51 min
#
# Evaluation: 30
# Evaluating at vz = -224.24242424242425
# Value: 3.422285406676093e-05
# Time to integrate: 1.44s
# Time elapsed: 0.53 min
#
# Evaluation: 31
# Evaluating at vz = -218.1818181818182
# Value: 3.683040565408035e-05
# Time to integrate: 0.47s
# Time elapsed: 0.54 min
#
# Evaluation: 32
# Evaluating at vz = -212.12121212121212
# Value: 4.3160108449508786e-05
# Time to integrate: 0.52s
# Time elapsed: 0.55 min
#
# Evaluation: 33
# Evaluating at vz = -206.06060606060606
# Value: 5.458131007015751e-05
# Time to integrate: 0.43s
# Time elapsed: 0.56 min
#
# Evaluation: 34
# Evaluating at vz = -200.0
# Value: 7.047064697437005e-05
# Time to integrate: 0.43s
# Time elapsed: 0.57 min
#
# Evaluation: 35
# Evaluating at vz = -193.93939393939394
# Value: 8.898742341962043e-05
# Time to integrate: 0.51s
# Time elapsed: 0.57 min
#
# Evaluation: 36
# Evaluating at vz = -187.87878787878788
# Value: 0.00010758728181329758
# Time to integrate: 0.5s
# Time elapsed: 0.58 min
#
# Evaluation: 37
# Evaluating at vz = -181.8181818181818
# Value: 0.00012947063965448212
# Time to integrate: 0.46s
# Time elapsed: 0.59 min
#
# Evaluation: 38
# Evaluating at vz = -175.75757575757575
# Value: 0.00015923479532761086
# Time to integrate: 0.51s
# Time elapsed: 0.6 min
#
# Evaluation: 39
# Evaluating at vz = -169.6969696969697
# Value: 0.00020488236612144678
# Time to integrate: 0.5s
# Time elapsed: 0.61 min
#
# Evaluation: 40
# Evaluating at vz = -163.63636363636363
# Value: 0.0002704757691403127
# Time to integrate: 0.43s
# Time elapsed: 0.61 min
#
# Evaluation: 41
# Evaluating at vz = -157.57575757575756
# Value: 0.0003614665214380982
# Time to integrate: 0.42s
# Time elapsed: 0.62 min
#
# Evaluation: 42
# Evaluating at vz = -151.51515151515153
# Value: 0.0004826487808004238
# Time to integrate: 0.44s
# Time elapsed: 0.63 min
#
# Evaluation: 43
# Evaluating at vz = -145.45454545454547
# Value: 0.0006378198247747612
# Time to integrate: 0.38s
# Time elapsed: 0.63 min
#
# Evaluation: 44
# Evaluating at vz = -139.39393939393938
# Value: 0.0008170788850653993
# Time to integrate: 0.53s
# Time elapsed: 0.64 min
#
# Evaluation: 45
# Evaluating at vz = -133.33333333333331
# Value: 0.001013929787771603
# Time to integrate: 0.44s
# Time elapsed: 0.65 min
#
# Evaluation: 46
# Evaluating at vz = -127.27272727272725
# Value: 0.001229367419905123
# Time to integrate: 0.41s
# Time elapsed: 0.66 min
#
# Evaluation: 47
# Evaluating at vz = -121.21212121212119
# Value: 0.0014575529229209788
# Time to integrate: 0.43s
# Time elapsed: 0.66 min
#
# Evaluation: 48
# Evaluating at vz = -115.15151515151513
# Value: 0.0016978467016210326
# Time to integrate: 0.47s
# Time elapsed: 0.67 min
#
# Evaluation: 49
# Evaluating at vz = -109.09090909090912
# Value: 0.0019520048726914502
# Time to integrate: 0.5s
# Time elapsed: 0.68 min
#
# Evaluation: 50
# Evaluating at vz = -103.03030303030306
# Value: 0.0022300211424828415
# Time to integrate: 0.41s
# Time elapsed: 0.69 min
#
# Evaluation: 51
# Evaluating at vz = -96.969696969697
# Value: 0.0025337389965512883
# Time to integrate: 0.51s
# Time elapsed: 0.7 min
#
# Evaluation: 52
# Evaluating at vz = -90.90909090909093
# Value: 0.002864543868016062
# Time to integrate: 0.49s
# Time elapsed: 0.7 min
#
# Evaluation: 53
# Evaluating at vz = -84.84848484848487
# Value: 0.0032365538312396896
# Time to integrate: 0.52s
# Time elapsed: 0.71 min
#
# Evaluation: 54
# Evaluating at vz = -78.78787878787881
# Value: 0.003661895633099748
# Time to integrate: 0.49s
# Time elapsed: 0.72 min
#
# Evaluation: 55
# Evaluating at vz = -72.72727272727275
# Value: 0.00415036495002547
# Time to integrate: 0.47s
# Time elapsed: 0.73 min
#
# Evaluation: 56
# Evaluating at vz = -66.66666666666669
# Value: 0.004697824350188982
# Time to integrate: 0.44s
# Time elapsed: 0.74 min
#
# Evaluation: 57
# Evaluating at vz = -60.60606060606062
# Value: 0.005287540949885544
# Time to integrate: 0.51s
# Time elapsed: 0.74 min
#
# Evaluation: 58
# Evaluating at vz = -54.54545454545456
# Value: 0.005914452175708698
# Time to integrate: 0.47s
# Time elapsed: 0.75 min
#
# Evaluation: 59
# Evaluating at vz = -48.4848484848485
# Value: 0.006554141748103462
# Time to integrate: 0.47s
# Time elapsed: 0.76 min
#
# Evaluation: 60
# Evaluating at vz = -42.424242424242436
# Value: 0.007178349811856117
# Time to integrate: 0.59s
# Time elapsed: 0.77 min
#
# Evaluation: 61
# Evaluating at vz = -36.363636363636374
# Value: 0.007764039793447302
# Time to integrate: 0.71s
# Time elapsed: 0.78 min
#
# Evaluation: 62
# Evaluating at vz = -30.30303030303031
# Value: 0.008292195296925277
# Time to integrate: 0.72s
# Time elapsed: 0.79 min
#
# Evaluation: 63
# Evaluating at vz = -24.24242424242425
# Value: 0.008759735715535698
# Time to integrate: 0.74s
# Time elapsed: 0.81 min
#
# Evaluation: 64
# Evaluating at vz = -18.181818181818187
# Value: 0.009143788486018592
# Time to integrate: 0.75s
# Time elapsed: 0.82 min
#
# Evaluation: 65
# Evaluating at vz = -12.121212121212125
# Value: 0.00941188150096471
# Time to integrate: 0.84s
# Time elapsed: 0.83 min
#
# Evaluation: 66
# Evaluating at vz = -6.060606060606062
# Value: 0.00955708213651644
# Time to integrate: 0.82s
# Time elapsed: 0.85 min
#
# Evaluation: 67
# Evaluating at vz = 0.0
# Value: 0.009591034833008867
# Time to integrate: 0.87s
# Time elapsed: 0.86 min
#
# Evaluation: 68
# Evaluating at vz = 6.060606060606062
# Value: 0.009494485759838212
# Time to integrate: 0.76s
# Time elapsed: 0.87 min
#
# Evaluation: 69
# Evaluating at vz = 12.121212121212125
# Value: 0.009243654039221548
# Time to integrate: 0.78s
# Time elapsed: 0.89 min
#
# Evaluation: 70
# Evaluating at vz = 18.181818181818187
# Value: 0.008882218627516774
# Time to integrate: 0.8s
# Time elapsed: 0.9 min
#
# Evaluation: 71
# Evaluating at vz = 24.24242424242425
# Value: 0.008423818412868819
# Time to integrate: 0.73s
# Time elapsed: 0.91 min
#
# Evaluation: 72
# Evaluating at vz = 30.30303030303031
# Value: 0.007910078153051937
# Time to integrate: 0.69s
# Time elapsed: 0.92 min
#
# Evaluation: 73
# Evaluating at vz = 36.363636363636374
# Value: 0.007346291041211168
# Time to integrate: 0.69s
# Time elapsed: 0.94 min
#
# Evaluation: 74
# Evaluating at vz = 42.424242424242436
# Value: 0.006760234070030322
# Time to integrate: 0.67s
# Time elapsed: 0.95 min
#
# Evaluation: 75
# Evaluating at vz = 48.4848484848485
# Value: 0.006181029146708907
# Time to integrate: 0.63s
# Time elapsed: 0.96 min
#
# Evaluation: 76
# Evaluating at vz = 54.54545454545456
# Value: 0.005639022426480746
# Time to integrate: 0.55s
# Time elapsed: 0.97 min
#
# Evaluation: 77
# Evaluating at vz = 60.60606060606062
# Value: 0.005158777044861102
# Time to integrate: 0.51s
# Time elapsed: 0.97 min
#
# Evaluation: 78
# Evaluating at vz = 66.66666666666669
# Value: 0.004717836474385195
# Time to integrate: 0.51s
# Time elapsed: 0.98 min
#
# Evaluation: 79
# Evaluating at vz = 72.72727272727275
# Value: 0.004298207783801361
# Time to integrate: 0.49s
# Time elapsed: 0.99 min
#
# Evaluation: 80
# Evaluating at vz = 78.78787878787881
# Value: 0.0038872609682105326
# Time to integrate: 0.48s
# Time elapsed: 1.0 min
#
# Evaluation: 81
# Evaluating at vz = 84.84848484848487
# Value: 0.0034830662808001305
# Time to integrate: 0.53s
# Time elapsed: 1.01 min
#
# Evaluation: 82
# Evaluating at vz = 90.90909090909088
# Value: 0.00308114227016902
# Time to integrate: 0.54s
# Time elapsed: 1.02 min
#
# Evaluation: 83
# Evaluating at vz = 96.96969696969694
# Value: 0.0026850616229733906
# Time to integrate: 0.48s
# Time elapsed: 1.03 min
#
# Evaluation: 84
# Evaluating at vz = 103.030303030303
# Value: 0.0022954845701141755
# Time to integrate: 0.46s
# Time elapsed: 1.03 min
#
# Evaluation: 85
# Evaluating at vz = 109.09090909090907
# Value: 0.0019244348809214148
# Time to integrate: 0.41s
# Time elapsed: 1.04 min
#
# Evaluation: 86
# Evaluating at vz = 115.15151515151513
# Value: 0.0015907461144321565
# Time to integrate: 0.45s
# Time elapsed: 1.05 min
#
# Evaluation: 87
# Evaluating at vz = 121.21212121212125
# Value: 0.0013003766265909536
# Time to integrate: 0.41s
# Time elapsed: 1.05 min
#
# Evaluation: 88
# Evaluating at vz = 127.27272727272725
# Value: 0.0010485301651162432
# Time to integrate: 0.33s
# Time elapsed: 1.06 min
#
# Evaluation: 89
# Evaluating at vz = 133.33333333333337
# Value: 0.0008288029908190246
# Time to integrate: 0.42s
# Time elapsed: 1.07 min
#
# Evaluation: 90
# Evaluating at vz = 139.39393939393938
# Value: 0.0006425749377663978
# Time to integrate: 0.42s
# Time elapsed: 1.07 min
#
# Evaluation: 91
# Evaluating at vz = 145.4545454545455
# Value: 0.00048824801219303536
# Time to integrate: 0.36s
# Time elapsed: 1.08 min
#
# Evaluation: 92
# Evaluating at vz = 151.5151515151515
# Value: 0.0003625622846491807
# Time to integrate: 0.42s
# Time elapsed: 1.09 min
#
# Evaluation: 93
# Evaluating at vz = 157.57575757575762
# Value: 0.00026329379324505097
# Time to integrate: 0.42s
# Time elapsed: 1.09 min
#
# Evaluation: 94
# Evaluating at vz = 163.63636363636363
# Value: 0.00018517198568409013
# Time to integrate: 0.46s
# Time elapsed: 1.1 min
#
# Evaluation: 95
# Evaluating at vz = 169.69696969696975
# Value: 0.00012474781256029677
# Time to integrate: 0.52s
# Time elapsed: 1.11 min
#
# Evaluation: 96
# Evaluating at vz = 175.75757575757575
# Value: 8.01801220685386e-05
# Time to integrate: 1.5s
# Time elapsed: 1.13 min
#
# Evaluation: 97
# Evaluating at vz = 181.81818181818176
# Value: 5.0163965226570634e-05
# Time to integrate: 0.5s
# Time elapsed: 1.14 min
#
# Evaluation: 98
# Evaluating at vz = 187.87878787878788
# Value: 3.1883992748897987e-05
# Time to integrate: 0.5s
# Time elapsed: 1.15 min
#
# Evaluation: 99
# Evaluating at vz = 193.93939393939388
# Value: 2.2209895650399428e-05
# Time to integrate: 0.48s
# Time elapsed: 1.16 min
#
# Evaluation: 100
# Evaluating at vz = 200.0
# Value: 1.7779609640195602e-05
# Time to integrate: 0.51s
# Time elapsed: 1.17 min

# %%
gaia_data2 = search_phase_space(0., 0., 0., 0., 0., 0., 0.05, 0.)
R, phi, z = rect_to_cyl(gaia_data2[:,0], gaia_data2[:,1], gaia_data2[:,2])
vR, vT, vz = rect_to_cyl_vec(gaia_data2[:,3], gaia_data2[:,4], gaia_data2[:,5], gaia_data2[:,0], gaia_data2[:,1], gaia_data2[:,2])
gaia_data2 = np.stack((R, phi, z, vR, vT, vz), axis=1)

# %%
from galpy.df import quasiisothermaldf
from galpy.potential import MWPotential2014
from galpy.actionAngle import actionAngleStaeckel
from galpy.actionAngle import actionAngleAdiabatic
import numpy 

aAS= actionAngleStaeckel(pot=MWPotential2014,delta=0.45,c=True)
qdfS= quasiisothermaldf(1./3.,0.2,0.1,1.,1.,pot=MWPotential2014,aA=aAS,cutcounter=True)

#initialize mean values for (R,vR,vT,z,vz)
mR,mz = 8.3/8. ,0./8. #convert to nat. units

vRs= np.linspace(-1,1,100) #odd endpoints because galpy uses natural units
vTs= np.linspace(0,2,100)
vzs= np.linspace(-1,1,100)

#Calculating the probability of vR without regard for vT or vz 
#is called marginalizing over the remaining probabilities.
#This is the opposite of conditional probability. 

pvR= np.array([qdfS.pvR(vR,mR,mz) for vR in vRs]) #uses Gauss-Legendre integration
pvT= np.array([qdfS.pvT(vT,mR,mz) for vT in vTs])
pvz= np.array([qdfS.pvz(vz,mR,mz) for vz in vzs])

#plot!
fig, ax = plt.subplots(1, 3, sharex='none', sharey='none', figsize=(20,5))

ax[0].plot(vRs*220, pvR/numpy.sum(pvR)/(vRs[1]-vRs[0])/220) #convert to physical units and normalize area to 1 
ax[0].set_title('vR', fontsize=20)
ax[1].plot(vTs*220, pvT/numpy.sum(pvT)/(vTs[1]-vTs[0])/220)
ax[1].set_title('vT', fontsize=20)
ax[2].plot(vRs*220, pvz/numpy.sum(pvR)/(vzs[1]-vzs[0])/220)
ax[2].set_title('vz', fontsize=20)


#above graphs overlayed
vs= np.linspace(-1,2,100)

pvR= np.array([qdfS.pvR(v,mR,mz) for v in vs])
pvT= np.array([qdfS.pvT(v,mR,mz) for v in vs])
pvz= np.array([qdfS.pvz(v,mR,mz) for v in vs])

fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(vs*220, pvR/numpy.sum(pvR)/(vs[1]-vs[0])/220, label='vR') #convert to physical units and normalize area to 1 
ax.plot(vs*220, pvT/numpy.sum(pvT)/(vs[1]-vs[0])/220, label='vT')
ax.plot(vs*220, pvz/numpy.sum(pvz)/(vs[1]-vs[0])/220, label='vz')
ax.hist(vR, bins=100, normed=True, label='vR_histogram', alpha=0.5)
ax.hist(vT, bins=100, normed=True, label='vT_histogram', alpha=0.5)
ax.hist(vz, bins=100, normed=True, label='vz_histogram', alpha=0.5)
legend = ax.legend(loc='upper left', shadow=True, fontsize='x-large')
legend.get_frame().set_facecolor('#F0F0F0')
plt.show()

# %%
import numpy as np
# overplotting qdf and kde integrated
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(v_input, vR_output/np.sum(vR_output)/(v_input[1]-v_input[0]), label='vR_kde_integrated') #normalized area to 1
ax.plot(v_input, vT_output/np.sum(vT_output)/(v_input[1]-v_input[0]), label='vT_kde_integrated')
ax.plot(v_input, vz_output/np.sum(vz_output)/(v_input[1]-v_input[0]), label='vz_kde_integrated')
ax.plot(vs*220, pvR/numpy.sum(pvR)/(vs[1]-vs[0])/220, label='vR_qdf_integrated')
ax.plot(vs*220, pvT/numpy.sum(pvT)/(vs[1]-vs[0])/220, label='vT_qdf_integrated')
ax.plot(vs*220, pvz/numpy.sum(pvz)/(vs[1]-vs[0])/220, label='vz_qdf_integrated')
ax.hist(vR, bins=100, normed=True, label='vR_histogram', alpha=0.5)
ax.hist(vT, bins=100, normed=True, label='vT_histogram', alpha=0.5)
ax.hist(vz, bins=100, normed=True, label='vz_histogram', alpha=0.5)
legend = ax.legend(loc='upper left', shadow=True, fontsize='x-large')
legend.get_frame().set_facecolor('#F0F0F0')
plt.savefig('gaia_zscore_cyl_integrated_10bw_hist')
plt.show()
