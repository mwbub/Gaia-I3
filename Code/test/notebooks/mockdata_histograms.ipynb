# %%
#Importing the required modules and general setup
import numpy as np
import matplotlib.pyplot as plt
from galpy.util.bovy_coords import *
import sys
sys.path.append('..')

#Importing qdf load data
samples_qdf = np.load('../mock_data/qdf/data/qdf sample cartesian physical.npy')

#Convert cylindrical to rectangular
R, phi, z = rect_to_cyl(samples_qdf[:,0], samples_qdf[:,1], samples_qdf[:,2])
vR, vT, vz = rect_to_cyl_vec(samples_qdf[:,3], samples_qdf[:,4], samples_qdf[:,5], samples_qdf[:,0], samples_qdf[:,1], samples_qdf[:,2])
samples_qdf = np.stack((R, phi, z, vR, vT, vz), axis=1)

#Print min/max/mean values for each parameter
print('#stars', len(samples_qdf))
print('min/max/mean (R)', min(samples_qdf[:,0]), max(samples_qdf[:,0]), np.mean(samples_qdf[:,0]))
print('min/max/mean (phi)', min(samples_qdf[:,1]), max(samples_qdf[:,1]), np.mean(samples_qdf[:,1]))
print('min/max/mean (z)', min(samples_qdf[:,2]), max(samples_qdf[:,2]), np.mean(samples_qdf[:,2]))
print('min/max/mean (vR)', min(samples_qdf[:,3]), max(samples_qdf[:,3]), np.mean(samples_qdf[:,3]))
print('min/max/mean (vT)', min(samples_qdf[:,4]), max(samples_qdf[:,4]), np.mean(samples_qdf[:,4]))
print('min/max/mean (vz)', min(samples_qdf[:,5]), max(samples_qdf[:,5]), np.mean(samples_qdf[:,5]))
print(np.std(samples_qdf[:,0]), np.std(samples_qdf[:,1]), np.std(samples_qdf[:,2]), np.std(samples_qdf[:,3]), np.std(samples_qdf[:,4]), np.std(samples_qdf[:,5]))
# Out:
# #stars 1700000
# min/max/mean (R) 7.500001243345344 8.49999953522708 7.969965199195673
# min/max/mean (phi) 1.6301135663532307e-08 6.283185038353656 3.1401285030845902
# min/max/mean (z) -0.49999834658428355 0.4999995739316849 -2.391397007444206e-06
# min/max/mean (vR) -236.34956909728945 238.89187384508756 0.11518528783826848
# min/max/mean (vT) 13.846286930361888 311.0204205652608 200.93815386013594
# min/max/mean (vz) -85.78838260434244 86.22172425821299 0.020116191019555998
# 0.2878949918700057 3.110438773375136 0.24372413462191325 46.24245682888362 33.43425893937589 19.6372819834462

# %%
print('Set of plots from cartesian physical mockdata file converted to cyl using galpy')

print('R Histogram')
plt.hist(R, bins=100)
plt.show()
print('phi Histogram')
plt.hist(phi, bins=100)
plt.show()
print('z Histogram')
plt.hist(z, bins=100)
plt.show()
print('vR Histogram')
plt.hist(vR, bins=100)
plt.show()
print('vT Histogram')
plt.hist(vT, bins=100)
plt.show()
print('vz Histogram')
plt.hist(vz, bins=100)
plt.show()
# Out:
# Set of plots from cartesian physical mockdata file converted to cyl using galpy
# R Histogram
# phi Histogram
# z Histogram
# vR Histogram
# vT Histogram
# vz Histogram

# %%
#Importing qdf load data
samples_qdf = np.load('../mock_data/qdf/data/qdf sample data.npy')

#Convert cylindrical to rectangular
R, phi, z = samples_qdf[:,0]*8., samples_qdf[:,1], samples_qdf[:,2]*8.
vR, vT, vz = samples_qdf[:,3]*220., samples_qdf[:,4]*220., samples_qdf[:,5]*220.
samples_qdf = np.stack((R, phi, z, vR, vT, vz), axis=1)

#Print min/max/mean for each parameter
print('#stars', len(samples_qdf))
print('min/max/mean (R)', min(samples_qdf[:,0]), max(samples_qdf[:,0]), np.mean(samples_qdf[:,0]))
print('min/max/mean (phi)', min(samples_qdf[:,1]), max(samples_qdf[:,1]), np.mean(samples_qdf[:,1]))
print('min/max/mean (z)', min(samples_qdf[:,2]), max(samples_qdf[:,2]), np.mean(samples_qdf[:,2]))
print('min/max/mean (vR)', min(samples_qdf[:,3]), max(samples_qdf[:,3]), np.mean(samples_qdf[:,3]))
print('min/max/mean (vT)', min(samples_qdf[:,4]), max(samples_qdf[:,4]), np.mean(samples_qdf[:,4]))
print('min/max/mean (vz)', min(samples_qdf[:,5]), max(samples_qdf[:,5]), np.mean(samples_qdf[:,5]))
print(np.std(samples_qdf[:,0]), np.std(samples_qdf[:,1]), np.std(samples_qdf[:,2]), np.std(samples_qdf[:,3]), np.std(samples_qdf[:,4]), np.std(samples_qdf[:,5]))
# Out:
# #stars 1700000
# min/max/mean (R) 7.500001243345344 8.49999953522708 7.969965199195673
# min/max/mean (phi) -0.062499793323035444 0.062499946741460616 -2.9892462593052575e-07
# min/max/mean (z) -0.49919960242070555 0.4991995194064611 0.00014353623215025265
# min/max/mean (vR) -236.34956909728942 238.89187384508764 0.11518528783829328
# min/max/mean (vT) 13.846286930361892 311.02042056526074 200.9381538601359
# min/max/mean (vz) -85.78838260434244 86.22172425821299 0.020116191019555998
# 0.2878949918700057 0.030465516827739157 0.28823420361611957 46.24245682888362 33.43425893937589 19.6372819834462

# %%
print('Set of plots from cyl natural mockdata converted to physical manually')

print('R Histogram')
plt.hist(R, bins=100)
plt.show()
print('phi Histogram')
plt.hist(phi, bins=100)
plt.show()
print('z Histogram')
plt.hist(z, bins=100)
plt.show()
print('vR Histogram')
plt.hist(vR, bins=100)
plt.show()
print('vT Histogram')
plt.hist(vT, bins=100)
plt.show()
print('vz Histogram')
plt.hist(vz, bins=100)
plt.show()
# Out:
# Set of plots from cyl natural mockdata converted to physical manually
# R Histogram
# phi Histogram
# z Histogram
# vR Histogram
# vT Histogram
# vz Histogram

# %%
#Importing qdf load data
samples_qdf = np.load('../mock_data/qdf/data/qdf sample data.npy')

# %%
print('Set of plots from cyl natural mockdata with no conversion')

print('R Histogram')
plt.hist(samples_qdf[:,0], bins=100)
plt.show()
print('phi Histogram')
plt.hist(samples_qdf[:,1], bins=100)
plt.show()
print('z Histogram')
plt.hist(samples_qdf[:,2], bins=100)
plt.show()
print('vR Histogram')
plt.hist(samples_qdf[:,3], bins=100)
plt.show()
print('vT Histogram')
plt.hist(samples_qdf[:,4], bins=100)
plt.show()
print('vz Histogram')
plt.hist(samples_qdf[:,5], bins=100)
plt.show()
# Out:
# Set of plots from cyl natural mockdata with no conversion
# R Histogram
# phi Histogram
# z Histogram
# vR Histogram
# vT Histogram
# vz Histogram
