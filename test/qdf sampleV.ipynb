# %%
import numpy as np
#import qdf related things
from galpy.potential import MWPotential2014
from galpy.actionAngle import actionAngleAdiabatic
from galpy.df import quasiisothermaldf
aA= actionAngleAdiabatic(pot=MWPotential2014,c=True)

# set up qdf
qdf= quasiisothermaldf(1./3.,0.2,0.1,1.,1.,pot=MWPotential2014,aA=aA,cutcounter=True)

# %%
r = np.arange(0., 1., 0.1)
z = np.arange(0., 1., 0.1)
rv, zv = np.meshgrid(r,z)
rv = rv.reshape(-1,1)
zv = zv.reshape(-1,1)
grid = np.concatenate((rv,zv),axis = 1)
grid_with_v = np.empty((grid.shape[0], 5))
for i in range(grid.shape[0]):
    vR, vT, vz = qdf.sampleV(grid[i][0], grid[i][1])[0]
    grid_with_v[i] = np.array([grid[i][0], grid[i][1], vR, vT, vz])
print(grid_with_v)

# %%
sum_of_comp = np.empty((grid.shape[0],5))
for i in range(grid.shape[0]):
    r = grid[i][0]
    z = grid[i][1]
    sum_of_comp[i] = np.array([r, z, r+z, r-z, r*z])
print(sum_of_comp)

# %%
print(np.shape(sum_of_comp))

# %%
print(np.shape(grid_with_v))

# %% [markdown]
# After trying to sample V on 1000 stars and compare the speed with other computation with the same amount of data, I concluded that qdf sample V is indeed too slow.

# %%
for i in range(1, 10):
    for j in range(1, 10):
        vR, vT, vz = qdf.sampleV(float(i), float(j))[0]
print('finished')
# Out:
# c:\users\user\anaconda3\lib\site-packages\galpy\df_src\quasiisothermaldf.py:266: RuntimeWarning: divide by zero encountered in log
#   -kappa*jr*numpy.exp(-2.*lnsr)
#
# Optimization terminated successfully.
#          Current function value: 77.404337
#          Iterations: 2
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 198.764061
#          Iterations: 3
#          Function evaluations: 57
# Optimization terminated successfully.
#          Current function value: 381.210616
#          Iterations: 3
#          Function evaluations: 48
# Optimization terminated successfully.
#          Current function value: 275313.546994
#          Iterations: 2
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 275455.262772
#          Iterations: 2
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 275593.500922
# ...

# %%
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
vR, vT, vz = qdf.sampleV(0.6, 0.5)[0]
print('finished')
# Out:
# c:\users\user\anaconda3\lib\site-packages\galpy\df_src\quasiisothermaldf.py:266: RuntimeWarning: divide by zero encountered in log
#   -kappa*jr*numpy.exp(-2.*lnsr)
#
# Optimization terminated successfully.
#          Current function value: 35.684056
#          Iterations: 2
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 35.684056
#          Iterations: 2
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 35.684056
#          Iterations: 2
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 35.684056
#          Iterations: 2
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 35.684056
#          Iterations: 2
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 35.684056
# ...

# %%
print(vR, vT, vz)
# Out:
# 0.7135174887673493 1.321220364747478 -0.1459732248493434
